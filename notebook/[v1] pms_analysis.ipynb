# %%
import os
import sys
import time
import numpy as np

# 프로젝트 루트 디렉토리 설정
os.chdir("/home/youngjins/project/belief_trading")

# lib 하위 경로 추가
sys.path.append("/home/youngjins/project/belief_trading/lib/")
sys.path.append("/home/youngjins/project/belief_trading/lib/pymarketsim")

# 환경 임포트
from lib.pymarketsim.marketsim.wrappers.MM_wrapper import MMEnv
from lib.policy import policyRandom1

# %%
# 매개 변수 선언 -> 노이즈 트레이더
seed = 0
np.random.seed(seed)

num_assets = 1
normalizers = {"fundamental": 1.2e5, "invt": 10, "cash": 5e5}
beta_params = {"a_buy": 0.5, "b_buy": 0.5, "a_sell": 0.5, "b_sell": 0.5}

# %%
# 강화학습 관련 변수 선언
env = MMEnv(
    num_background_agents=25,
    sim_time=1000,
    num_assets=num_assets,
    lam=0.1,
    mean=1e5,
    r=0.05,
    shock_var=5e6,
    q_max=10,
    pv_var=5e6,
    shade=[250, 500],
    normalizers=normalizers,
    beta_params=beta_params,
)

target_agent = policyRandom1()

# %%
# 시뮬레이션 시작
state, info = env.reset()
done = False
episode_reward = 0
history_dict = dict()

# 1개 에피소드 실행 (소요 시간 측정)
start_time = time.time()
while not done:

    action = target_agent.get_action(state)

    state, reward, terminated, truncated, info = env.step(action)

    episode_reward += reward

    # # 현재 상태에서 필요한 정보 추출
    # history_dict["mid_price"].append((info["best_bid"] + info["best_ask"]) / 2)
    # history_dict["best_bid"].append(info["best_bid"])
    # history_dict["best_ask"].append(info["best_ask"])
    # history_dict["reward"].append(reward)
    # history_dict["cumulative_reward"].append(episode_reward)
    # history_dict["pnl"].append(info["pnl"])
    # history_dict["holdings"].append(info["holdings"])
    # history_dict["time"].append(info["current_time"])
    # history_dict["action"].append(action_)
    # history_dict["order_size"].append(env.parent_order_size)  # debuging
    # history_dict["direction"].append(env.direction)  # debuging

    print(state)

end_time = time.time()
print(f"Execution time: {end_time - start_time} seconds")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-e636604a3f35> in <cell line: 2>()
#       1 # 시뮬레이션 시작
# ----> 2 state, info = env.reset()
#       3 done = False
#       4 episode_reward = 0
#       5 history_dict = dict()
#
# ~/project/belief_trading/lib/pymarketsim/marketsim/wrappers/MM_wrapper.py in reset(self, seed, options)
#     268         # Run until the MM enters.
#     269         # self.run_agents_only() #TODO: run agent only could exclude the arrival of MM.
# --> 270         _, end = self.run_until_next_MM_arrival()
#     271
#     272         if end:
#
# ~/project/belief_trading/lib/pymarketsim/marketsim/wrappers/MM_wrapper.py in run_until_next_MM_arrival(self)
#     415             reward = current_value - self.MM.last_value
#     416             self.MM.last_value = current_value
# --> 417             self.update_obs()
#     418
#     419             return reward / self.normalizers["reward"], False
#
# ~/project/belief_trading/lib/pymarketsim/marketsim/wrappers/MM_wrapper.py in update_obs(self)
#     160     def update_obs(self):
#     161         time_left = self.sim_time - self.time
# --> 162         fundamental_value = self.markets[0].fundamental.get_value_at(self.time)
#     163         best_ask = self.markets[0].order_book.get_best_ask()
#     164         best_bid = self.markets[0].order_book.get_best_bid()
#
# ~/project/belief_trading/lib/pymarketsim/marketsim/fundamental/lazy_mean_reverting.py in get_value_at(self, time)
#      55         """
#      56         if time not in self.fundamental_values:
# ---> 57             self._generate_at(time)
#      58         return self.fundamental_values[time]
#      59
#
# ~/project/belief_trading/lib/pymarketsim/marketsim/fundamental/lazy_mean_reverting.py in _generate_at(self, t)
#      32         dt = t - self.latest_t
#      33
# ---> 34         shocks = torch.randn(dt) * self.shock_std + self.shock_mean
#      35         weights = torch.pow(1 - self.r, torch.arange(dt, dtype=torch.float32))
#      36         total_shock = torch.sum(weights * shocks)
#
# RuntimeError: Trying to create tensor with negative dimension -567: [-567]
