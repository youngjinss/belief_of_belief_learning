# %%
import datetime
from binance_historical_data import BinanceDataDumper

data_dumper = BinanceDataDumper(
    path_dir_where_to_dump="../data/binance/",
    asset_class="um",  # spot, um, cm
    data_type="aggTrades",  # aggTrades, klines, trades
    data_frequency="1h",
)

# %%
data_dumper.dump_data(
    tickers=["BTCUSDT"],
    date_start=datetime.date(2022, 6, 1),
    date_end=None,
    is_to_update_existing=True,
)
# Out:
# ---> Found overall tickers: 460
# ---> Filter to asked tickers: 1
# ------> Tickers left: 1
# Download full data for 1 tickers:
# ---> Data will be saved here: /home/youngjins/project/belief_trading/data/binance/um
# ---> Data Frequency:
# ---> Start Date: 20220601
# ---> End Date: 20250403
# Tickers:   0%|          | 0/1 [00:00<?, ?it/s]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/binance_historical_data/data_dumper.py", line 233, in get_min_start_date_for_ticker
#     date_obj = datetime.datetime.strptime(date_str, '%Y-%m')
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '1682c07a5127-c000' does not match format '%Y-%m'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/logging/__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/logging/__init__.py", line 925, in format
#     return fmt.format(record)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/logging/__init__.py", line 664, in format
#     record.message = record.getMessage()
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/asyncio/base_events.py", line 563, in run_forever
#     self._run_once()
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/asyncio/base_events.py", line 1844, in _run_once
#     handle._run()
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2974, in run_cell
#     result = self._run_cell(
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3029, in _run_cell
#     return runner(coro)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3256, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3472, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3552, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_13351/2141428868.py", line 1, in <cell line: 1>
#     data_dumper.dump_data(
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/char/main.py", line 169, in wrapper
#     return func_to_check(*args, **kwargs)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/binance_historical_data/data_dumper.py", line 141, in dump_data
#     self._download_data_for_1_ticker(
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/char/main.py", line 169, in wrapper
#     return func_to_check(*args, **kwargs)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/binance_historical_data/data_dumper.py", line 398, in _download_data_for_1_ticker
#     min_start_date = self.get_min_start_date_for_ticker(ticker)
#   File "/home/youngjins/miniconda3/envs/belief_pred/lib/python3.8/site-packages/binance_historical_data/data_dumper.py", line 249, in get_min_start_date_for_ticker
#     LOGGER.error('Min date not found: ', e)
# Message: 'Min date not found: '
# Arguments: (ValueError("time data '1682c07a5127-c000' does not match format '%Y-%m'"),)
# monthly files to download:   0%|          | 0/34 [00:00<?, ?files/s]
# [WARNING] Unable to download raw file:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/belief_pred/lib/python3.8/site-packages/mpire/pool.py in imap_unordered(self, func, iterable_of_args, iterable_len, max_tasks_active, chunk_size, n_splits, worker_lifespan, progress_bar, worker_init, worker_exit, task_timeout, worker_init_timeout, worker_exit_timeout, progress_bar_options, progress_bar_style)
#     761                             try:
# --> 762                                 yield imap_iterator.next(block=True, timeout=0.01)
#     763                                 n_active -= 1
#
# ~/miniconda3/envs/belief_pred/lib/python3.8/site-packages/mpire/async_result.py in next(self, block, timeout)
#     160             while not self._items:
# --> 161                 timed_out = not self._condition.wait(timeout=timeout)
#     162                 if timed_out:
#
# ~/miniconda3/envs/belief_pred/lib/python3.8/threading.py in wait(self, timeout)
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_13351/2141428868.py in <cell line: 1>()
# ----> 1 data_dumper.dump_data(
#       2     tickers=["BTCUSDT"],
#       3     date_start=datetime.date(2022, 6, 1),
#       4     date_end=None,
#       5     is_to_update_existing=True,
#
# ~/miniconda3/envs/belief_pred/lib/python3.8/site-packages/char/main.py in wrapper(*args, **kwargs)
#     167
#     168             #####
# --> 169             return func_to_check(*args, **kwargs)
#     170         return wrapper
#     171     if function:
#
# ~/miniconda3/envs/belief_pred/lib/python3.8/site-packages/binance_historical_data/data_dumper.py in dump_data(self, tickers, date_start, date_end, is_to_update_existing, int_max_tickers_to_get, tickers_to_exclude)
#     139             # 1) Download all monthly data
#     140             if self._data_type != "metrics" and (date_end_first_day_of_month - relativedelta(days=1) > date_start):
# --> 141                 self._download_data_for_1_ticker(
#     142                     ticker=ticker,
#     143                     date_start=date_start,
#
# ~/miniconda3/envs/belief_pred/lib/python3.8/site-packages/char/main.py in wrapper(*args, **kwargs)
#     167
#     168             #####
# --> 169             return func_to_check(*args, **kwargs)
#     170         return wrapper
#     171     if function:
#
# ~/miniconda3/envs/belief_pred/lib/python3.8/site-packages/binance_historical_data/data_dumper.py in _download_data_for_1_ticker(self, ticker, date_start, date_end, timeperiod_per_file, is_to_update_existing)
#     450         # with WorkerPool(n_jobs=processes, use_dill=True) as pool:
#     451         with WorkerPool(n_jobs=processes) as pool:
# --> 452             list_saved_dates = list(tqdm(
#     453                 pool.imap_unordered(
#     454                     self._download_data_for_1_ticker_1_date,
#
# ~/miniconda3/envs/belief_pred/lib/python3.8/site-packages/tqdm/notebook.py in __iter__(self)
#     248         try:
#     249             it = super().__iter__()
# --> 250             for obj in it:
#     251                 # return super(tqdm...) will not catch exception
#     252                 yield obj
#
# ~/miniconda3/envs/belief_pred/lib/python3.8/site-packages/tqdm/std.py in __iter__(self)
#    1179
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#    1183                 # Update and possibly print the progressbar.
#
# ~/miniconda3/envs/belief_pred/lib/python3.8/site-packages/mpire/pool.py in imap_unordered(self, func, iterable_of_args, iterable_len, max_tasks_active, chunk_size, n_splits, worker_lifespan, progress_bar, worker_init, worker_exit, task_timeout, worker_init_timeout, worker_exit_timeout, progress_bar_options, progress_bar_style)
#     796
#     797                 except KeyboardInterrupt:
# --> 798                     self._handle_exception()
#     799
#     800         finally:
#
# ~/miniconda3/envs/belief_pred/lib/python3.8/site-packages/mpire/pool.py in _handle_exception(self)
#     924
#     925         # Raise
# --> 926         raise exception
#     927
#     928     def stop_and_join(self, keep_alive: bool = False) -> None:
#
# KeyboardInterrupt:
