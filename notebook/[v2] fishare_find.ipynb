# %%
import pandas as pd

portfolios_df = pd.read_csv("../data/fishare_portfolios.csv")
portfolios_df
# Out:
#                             sector registration_date  owner_id     1      2  \
# 0                       Households        1995-12-31        47   170    NaN
# 1                       Households        1995-12-31        85   170  516.0
# 2          Government institutions        1995-12-31       250   770  982.0
# 3       Non-Financial corporations        1995-12-31       952   328    NaN
# 4                       Households        1995-12-31      1265   962  170.0
# ...                            ...               ...       ...   ...    ...
# 197142                  Households        2016-12-31   1307758   432  412.0
# 197143                  Households        2016-12-31   1307801  1359    NaN
# 197144                  Households        2016-12-31   1307809    30    NaN
# 197145                  Households        2016-12-31   1307828   856  472.0
# 197146                  Households        2016-12-31   1308349   591    NaN
#
# ...

# %%
signatures_df = pd.read_csv("../data/fishare_signatures.csv")
signatures_df
# Out:
#                             sector registration_date  owner_id         1  \
# 0       Non-Financial corporations        1995-12-31   1162756  0.400000
# 1                       Households        1995-12-31    589052  1.000000
# 2                       Households        1995-12-31     87479  0.400000
# 3                       Households        1995-12-31    900157  0.500000
# 4                       Households        1995-12-31    941383  0.171429
# ...                            ...               ...       ...       ...
# 197142                  Households        2016-12-31     20114  0.392252
# 197143                  Households        2016-12-31    522415  0.109290
# 197144  Non-Financial corporations        2016-12-31    428955  0.053816
# 197145             EU institutions        2016-12-31   1019956  0.062417
# 197146                  Households        2016-12-31   1279977  0.096203
#
#                2         3         4         5         6         7  ...  461  \
# ...
