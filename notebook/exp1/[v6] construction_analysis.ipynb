# %% [markdown]
# ### 수식 적용:
# $ b_{i, l}^t (is^t) = Pr(is^t \mid b_{i, l}^{t-1}, a_i^{t-1}, o_i^t) = \alpha \sum_{is^{t-1}} b_{i, l} (is^{t-1}) \sum_{a_j^{t-1}} Pr (a_j^{t-1} \mid \theta_{j, l-1}^{t-1}) T(s^{t-1}, a^{t-1}, s^t) \times O_i (s^t, a^{t-1}, o_i^t) \sum_{o_j^t} O_j(s^t, a^{t-1}, o_j^t) \tau (b_{j,l-1}^{t-1}, a_j^{t-1}, o_j^t, b_{l-1}^t) $

# %%
import os
import sys
import numpy as np

# 프로젝트 디렉토리 경로 설정
project_dir = "/Users/youngjins/Desktop/codes/25_belief/belief_trading"
print(f"프로젝트 디렉토리: {project_dir}")
os.chdir(project_dir)
sys.path.append(project_dir + "/lib/AmortizedNestedReasoning/")
sys.path.append(project_dir + "/lib/AmortizedNestedReasoning/Construction")

from stable_baselines3.common.env_checker import check_env
from lib.AmortizedNestedReasoning.Construction.envs.constructionGym import (
    ConstructionGymEnv,
)
from lib.AmortizedNestedReasoning.Construction.envs import construction_sample
from lib.AmortizedNestedReasoning.Construction.utils.construction_data import (
    multi_agent_state_to_state_tensor,
    multi_agent_state_tensor_to_state,
)
# Out:
# 프로젝트 디렉토리: /Users/youngjins/Desktop/codes/25_belief/belief_trading
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 13
#      10 sys.path.append(project_dir + "/lib/AmortizedNestedReasoning/Construction")
#      12 from stable_baselines3.common.env_checker import check_env
# ---> 13 from lib.AmortizedNestedReasoning.Construction.envs.constructionGym import ConstructionGymEnv
#      14 from lib.AmortizedNestedReasoning.Construction.envs import construction_sample
#      15 from lib.AmortizedNestedReasoning.Construction.utils.construction_data import multi_agent_state_to_state_tensor, multi_agent_state_tensor_to_state
#
# File ~/Desktop/codes/25_belief/belief_trading/lib/AmortizedNestedReasoning/Construction/envs/constructionGym.py:3
#       1 import gym
#       2 from gym import spaces
# ----> 3 import envs.construction as construction
# ...
